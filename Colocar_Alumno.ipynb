# %% [markdown]
# <a href="https://colab.research.google.com/github/rommelAM/Procesamiento_De_Datos/blob/main/Colocar_Alumno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from openpyxl import Workbook, load_workbook

# %%
from google.colab import files
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Carga de lista de estudiantes
df1 = pd.read_excel('/content/alumno-curso-ejemplo.xlsx')
df1
# Out:
#      Alumno    Curso
# 0  Alumno 1  Curso 1
# 1  Alumno 2  Curso 4
# 2  Alumno 3  Curso 1
# 3  Alumno 4  Curso 2
# 4  Alumno 5  Curso 3
# 5  Alumno 6  Curso 5

# %%
# Carga de lista de almuerzos

df2 = pd.read_excel('/content/alumno-mes-ejemplo.xlsx')
df2
# Out:
#     Nombre   Curso  1  2  3  4  5  6  7
# 0  Alumno 3    NaN  0  0  0  0  1  0  0
# 1  Alumno 1    NaN  1  1  1  1  1  0  0
# 2  Alumno 2    NaN  0  1  1  0  0  0  1
# 3  Alumno 4    NaN  0  1  1  1  1  1  1
# 4  Alumno 5    NaN  0  0  0  0  1  1  1
# 5  Alumno 2    NaN  0  1  1  0  0  0  1

# %%
#df2.iloc[:,1]=df1.iloc[:,1]

df2.iloc[:,1]='SIN CURSO'
df2
# Out:
#     Nombre       Curso  1  2  3  4  5  6  7
# 0  Alumno 3  SIN CURSO  0  0  0  0  1  0  0
# 1  Alumno 1  SIN CURSO  1  1  1  1  1  0  0
# 2  Alumno 2  SIN CURSO  0  1  1  0  0  0  1
# 3  Alumno 4  SIN CURSO  0  1  1  1  1  1  1
# 4  Alumno 5  SIN CURSO  0  0  0  0  1  1  1
# 5  Alumno 2  SIN CURSO  0  1  1  0  0  0  1

# %%
for j in range(len(df2.index)):
  for k in range(len(df1.index)):
            if df2.values[j,0] == df1.values[k,0]:
               #print('El valor a comparar es: '+df2.values[j,0]+' con '+df1.values[k,0]+' SI El curso es: '+df1.values[k,1])
               #print('El alumno '+df2.values[j,0]+' con cuso '+df2.values[j,1]+'Debe terner el curso'+df1.values[k,1])
              df2.iloc[j,1]=df1.values[k,1]

              #print('El valor a comparar es: '+df1.values[k,0]+' con '+df2.values[j,0]+ ' NO')
df2
# Out:
#     Nombre     Curso  1  2  3  4  5  6  7
# 0  Alumno 3  Curso 1  0  0  0  0  1  0  0
# 1  Alumno 1  Curso 1  1  1  1  1  1  0  0
# 2  Alumno 2  Curso 4  0  1  1  0  0  0  1
# 3  Alumno 4  Curso 2  0  1  1  1  1  1  1
# 4  Alumno 5  Curso 3  0  0  0  0  1  1  1
# 5  Alumno 2  Curso 4  0  1  1  0  0  0  1

# %%
df2
# Out:
#     Nombre     Curso  1  2  3  4  5  6  7
# 0  Alumno 3  Curso 1  0  0  0  0  1  0  0
# 1  Alumno 1  Curso 1  1  1  1  1  1  0  0
# 2  Alumno 2  Curso 4  0  1  1  0  0  0  1
# 3  Alumno 4  Curso 2  0  1  1  1  1  1  1
# 4  Alumno 5  Curso 3  0  0  0  0  1  1  1
# 5  Alumno 2  Curso 4  0  1  1  0  0  0  1

# %%
df2.to_excel('Resultado Reporte Alumno con Curso')
